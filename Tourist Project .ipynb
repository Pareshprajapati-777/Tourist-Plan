# %%
# import numpy as np
import folium 
import matplotlib.pyplot as plt
from folium.plugins import HeatMap
please=["Agra🕌","Goa🏖️","🗻Himachal Pradesh🗻","Thailand🏝️","Morisas🌄"]
price={1:2000,2:4000,3:5000,4:10000,5:12000}
km=[1845,2160,3015,7390,9600]
vehicle=["Car","Bus","Train","Flight"]
total=0
pie=[]
d = 0
p = 0
pac = 0
basic = 0
total = 0
data=["Travel","Food","Hotel","Ride activity","Other Expenses"]
pack=["Low","Mid","High"]
print("Welcome to Tourist Guy📍📍")

print("Where You Go Select ⛰️ :")
print("""\t Press 1. Agra🕌
         Press 2. Goa🏖️
         Press 3. Himachal Pradesh🗻
         Press 4. Thailand🏝️
         Press 5. Morisas🌄""")

x=int(input("    Enter Your Choise..."))
if x<=5 and x>0:
    p=int(input("   Enter How Many People To Go \n(More Then 10 People Get 10% Discount):"))
    if p>=1:
        d=int(input("   Enter How Many Day (min:5) :"))
        if d<=4:
            print(f"Not Have {d} Day Package of {please[x-1]}")
        else:
            print("""
                Press 1. Lower Pack
                Press 2. Mideam Pack
                press 3. High Pack""")
            pac=int(input("\t Enter your Favorite🤩🤩 Pack :"))
            if pac<=3 and pac>0:
                basic=price[x]
                if pac==2:
                    basic+=1000
                if pac==3:
                    basic+=2000
                total=basic*p*d
            else:
                print("Wrong Input!!!")
    else:
        print("Enter Valied Input!!!")
else:
    print("Enter Courect Choise !!!")
    
if d>4:
    print(f"""-------------------------------
        ------ TRIP SUMMARY ------
    You Please To Go is {please[x-1]}
    for {d} Day and {p} Peaple 
    With || {pack[pac-1]} Pack ||
    Your Tour Total {km[x-1]} K.M.
    your tour Per person 1/Day Cost :{basic}
    """)
    print("""
            Press 1. Conforming✅
            Press 2. Cansel❌
    """)
    yes=int(input("Enter Choise :"))
    if yes==1:
        if x==1 or x==2 or x==3:
            print("Select Travel Mode:")
            print("1. Car (₹6/km)")
            print("2. Bus (₹5/km)")
            print("3. Train (₹8/km)")
            print("4. Flight (₹15/km)")
            mode = int(input("Enter Mode No: "))
        else:
            mode=4
        rates={1:6, 2:5, 3:8, 4:15}
        fuel=km[x-1]*rates[mode]
        pie.append(fuel)
        fo=total*21//100
        pie.append(fo)
        ho=total*23//100
        pie.append(ho)
        ri=total*14.55//100
        pie.append(ri)
        ex=total*16.45//100
        pie.append(ex)
        print()
        print("----------------------------------")
        print(f"Estimated Fuel/Tickets Cost ({vehicle[mode-1]}): {fuel}")
        print(f"Food Cost :{fo}")
        print(f"Hotel Cost :{ho}")
        print(f"Ride activity Cost :{ri}")
        print(f"Other Expenses Cost :{ex}")
        print("-----------------------------------------")
        if p>10:
            dish=total*10//100
            print(f"A Special Offer For You 10% Discount ₹{dish}")
            print(f"==== Total Estimate Prise :{total-dish} =====") 
        else: 
            print(f"==== Total Estimate Prise :{total} =====") 
        print("___________________________________________")
        print()
        c=['yellow','red','blue','green','orange']
        plt.pie(pie, labels=data,colors=c,autopct='%1.1f%%', startangle=90,shadow=True,labeldistance=1.2,pctdistance=0.6,
           wedgeprops={'edgecolor':'black','linewidth':2},
           textprops={'fontsize':12,'color':'Black'},
           normalize=True)
        plt.title("--------Expense Distribution--------")
        plt.show()

        print()
        print(f"""You Tour Is Redy According To Map
        -----Ahmedabad To {please[x-1]}-----""")
        print()
       
        m = folium.Map(location=[23.02966, 72.65758], zoom_start=7)
        if x==1:
            print("Ahmedabad --> Udaipur --> Jaipur --> Agra Then Return")
            points = [
            ["Home",23.02966, 72.65758],
            ["Sabarmati Ashram", 23.0510, 72.5926],
            ["Akshardham Temple", 23.2152, 72.6498],
            ["Adalaj Stepwell", 23.0838, 72.5251],
            ["Kankaria Lake", 23.0015, 72.5597],
            ["Lake Pichola", 24.5775, 73.6770],
            ["Jag Mandir", 24.5849, 73.6721],
            ["Fateh Sagar Lake", 24.5926, 73.6649],
            ["Amber Fort",26.9855, 75.8513],
            ["Hawa Mahal",26.9239, 75.8267],
            ["Jantar Mantar",26.9258, 75.8265],
            ["City Palace",26.9270, 75.8231],
            ["Taj Mahal", 27.1751, 78.0421],
            ["Agra Fort", 27.1795, 78.0211],
            ["Itimad-ud-Daulah", 27.1618, 78.0260],
            ["Mehtab Bagh", 27.1850, 78.0216],
            ["Home",23.02966, 72.65758]
            ]
        elif x==2:
            print("Ahmedabad --> Vadodara --> Mumbai --> Goa (North Goa) And Goa (South Goa) Then Return")
            points = [
            ["Home",23.02966, 72.65758],
            ["Sabarmati Ashram", 23.0510, 72.5926],
            ["Akshardham Temple", 23.2152, 72.6498],
            ["Adalaj Stepwell", 23.0838, 72.5251],
            ["Kankaria Lake", 23.0015, 72.5597],
            ["Laxmi Vilas Palace", 22.3039, 73.1890],
            ["Sayaji Garden", 22.3072, 73.1812],
            ["Gateway of India", 18.9220, 72.8347],
            ["Marine Drive", 18.9430, 72.8238],
            ["Elephanta Caves", 18.9633, 72.9315],
            ["Baga Beach", 15.5553, 73.7517],
            ["Calangute Beach", 15.5439, 73.7553],
            ["Fort Aguada", 15.4989, 73.7743],
            ["Chapora Fort", 15.6016, 73.7360],
            ["Colva Beach", 15.2792, 73.9227],
            ["Benaulim Beach", 15.2510, 73.9242],
            ["Home",23.02966, 72.65758]
            ]
        elif x==3:  
            print("Ahmedabad -->Himachal Pradesh in --> Shimla --> Manali --> Dharamshala --> Dalhousie Then Return")
            points = [
            ["Home",23.02966, 72.65758],
            ["Sabarmati Ashram", 23.0510, 72.5926],
            ["City Palace", 24.5768, 73.6836],
            ["Lake Pichola", 24.5775, 73.6770],
            ["Amber Fort", 26.9855, 75.8513],
            ["Hawa Mahal", 26.9239, 75.8267],
            ["Mall Road", 31.1048, 77.1734],
            ["Jakhoo Temple", 31.1049, 77.1835],
            ["Kufri", 31.0978, 77.2670],
            ["Hadimba Temple", 32.2396, 77.1887],
            ["Solang Valley", 32.3160, 77.1570],
            ["Rohtang Pass", 32.3717, 77.2467],
            ["McLeod Ganj", 32.2426, 76.3219],
            ["Bhagsu Waterfall", 32.2460, 76.3346],
            ["Khajjiar", 32.5500, 76.0500],
            ["Dainkund Peak", 32.5330, 75.9830],
            ["Home",23.02966, 72.65758]
            ]
        elif x==4:
            print("Ahmedabad -->Thailand in --> Bangkok --> Pattaya --> Phuket --> Krabi Then Return")
            points = [
            ["Home",23.02966, 72.65758],
            ["Akshardham Temple", 23.2152, 72.6498],
            ["Adalaj Stepwell", 23.0838, 72.5251],
            ["Grand Palace ", 13.7500, 100.4913],
            ["Wat Arun ", 13.7437, 100.4889],
            ["Wat Pho ", 13.7465, 100.4930],
            ["Chatuchak Market ", 13.7999, 100.5500],
            ["Pattaya Beach ", 12.9236, 100.8825],
            ["Sanctuary of Truth ", 12.9736, 100.8894],
            ["Coral Island (Koh Larn) ", 12.9276, 100.7789],
            ["Patong Beach ", 7.8967, 98.2961],
            ["Big Buddha Phuket ", 7.8277, 98.3123],
            ["Phi Phi Island ", 7.7407, 98.7784],
            ["Railay Beach ", 8.0117, 98.8370],
            ["Ao Nang Beach ", 8.0458, 98.8120],
            ["Tiger Cave Temple ", 8.1277, 98.9222],
            ["Home",23.02966, 72.65758]
            ]
        elif x==5:
            print("""Ahmedabad -->Mauritius in --> West Mauritius --> South-West Mauritius --> Central Mauritius --> 
            North-East Mauritius --> Islands Around Mauritius Then Return""")
            points = [
            ["Home",23.02966, 72.65758],
            ["Flic en Flac Beach",20.2766, 57.3642],
            ["Casela Nature Parks",20.3144, 57.4023],
            ["Tamarin Bay",20.3256, 57.3706],
            ["Alexandra Falls",20.4255, 57.4627],
            ["Gris Gris Beach",20.5190, 57.5222],
            ["Rochester Falls",20.5003, 57.6000],
            ["Trou aux Cerfs (Volcano)",20.2644, 57.4958],
            ["Ganga Talao (Grand Bassin)",20.4975, 57.5020],
            ["Eureka House",20.3444, 57.5025],
            ["Pamplemousses Botanical Garden",20.1030, 57.5806],
            ["L’Aventure du Sucre",20.1048, 57.5805],
            ["Anse La Raie Beach",19.9848, 57.6256],
            ["Île aux Aigrettes",20.4205, 57.7426],
            ["Gabriel Island",19.8833, 57.6167],
            ["Flat Island",19.8869, 57.6375],
            ["Home",23.02966, 72.65758]
            ]

        icons = [
        "home","star","flag","leaf","fire","flag","tint","tree-conifer","tower","certificate","flash",
        "heart","globe","tree-deciduous","camera","leaf","home"
        ]
        colors = [
        "red","blue","green","purple","orange",
        "darkred","lightred","beige","darkblue",
        "darkgreen","cadetblue","darkpurple",
        "pink","lightblue","gray","darkgreen","red"
        ]
        for i,c in enumerate(points):
            folium.Marker(
                location=[c[1], c[2]],
                popup=f"<b>{c[0]}</b>",
                tooltip=f" {c[0]}",
                icon=folium.Icon(
                    color=colors[i],
                    icon=icons[i]
                )
                
            ).add_to(m)
            points2 = [[c[1], c[2]] for c in points]
            
            folium.PolyLine(
                locations=points2,
                color="black",
                weight=4,
                opacity=0.8
            ).add_to(m)
    
    else:
        print("ok, Your Tour Is Cansel ")
m
# Out:
# Welcome to Tourist Guy📍📍
# Where You Go Select ⛰️ :
# 	 Press 1. Agra🕌
#          Press 2. Goa🏖️
#          Press 3. Himachal Pradesh🗻
#          Press 4. Thailand🏝️
#          Press 5. Morisas🌄
